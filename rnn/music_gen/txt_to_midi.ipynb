# %%
from music21 import converter, corpus, instrument, midi, note, chord, pitch, stream
import numpy as np

# %%
temp = np.genfromtxt('gen_processed.txt', delimiter='\n', dtype=str)

for i in range(temp.shape[0]):
    temp[i] = temp[i].replace('<', '').replace('>','')
    
print(type(temp[0]))
notes = []
for i in temp:
    notes.append(i.split())

print(notes)
# Out:
# <class 'numpy.str_'>
# [['music21.note.Note', 'B-'], ['music21.note.Note', 'A'], ['music21.note.Note', 'G'], ['music21.note.Note', 'D'], ['music21.note.Note', 'F'], ['music21.note.Note', 'G'], ['music21.note.Note', 'F'], ['music21.note.Note', 'F'], ['music21.note.Note', 'D'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'B'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'F'], ['music21.note.Note', 'F'], ['music21.note.Note', 'C'], ['music21.note.Note', 'C'], ['music21.note.Note', 'G'], ['music21.note.Note', 'F'], ['music21.note.Note', 'D'], ['music21.note.Note', 'C'], ['music21.note.Note', 'B'], ['music21.note.Note', 'G'], ['music21.note.Note', 'E'], ['music21.note.Note', 'G'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B'], ['music21.note.Note', 'G'], ['music21.chord.Chord', 'B-1', 'G2'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'E'], ['music21.chord.Chord', 'B3', 'E3'], ['music21.note.Note', 'D'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'F'], ['music21.note.Note', 'G'], ['music21.note.Note', 'D'], ['music21.note.Note', 'E-'], ['music21.noe.Note', 'B'], ['music21.note.Note', 'D'], ['music21.chord.Chord', 'B-3', 'G4'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B'], ['music21.note.Note', 'D'], ['music21.note.Note', 'G'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B'], ['music21.note.Note', 'C'], ['music21.note.Note', 'B'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'C'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'B-'], ['music21.chord.Chord', 'F'], ['music21.note.Note', 'G'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'F'], ['music21.note.Note', 'G'], ['music21.note.Note', 'D'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'D'], ['music21.note.Note', 'F'], ['music21.note.Note', 'C'], ['music21.note.Note', 'E'], ['music21.note.Note', 'D'], ['music21.note.Note', 'G'], ['music21.note.Note', 'E'], ['music21.note.Note', 'C'], ['music21.note.Note', 'F'], ['music21.note.Note', 'E'], ['music21.chord.Chord', 'D4', 'F4'], ['music21.note.Note', 'E-'], ['music21.chord.Chord', 'E3', 'C4'], ['music21.chord.Chord', 'F3', 'A2'], ['music21.chord.Chord', 'B-4', 'F'], ['music21.note.Note', 'A'], ['music21.note.Note', 'D'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'G'], ['music21.note.Note', 'C'], ['music21.note.Note', 'C'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'A'], ['music21.chord.Chord', 'G'], ['music21.note.Note', 'A'], ['music21.note.Note', 'A'], ['music21.note.Note', 'B'], ['music21.note.Note', 'C'], ['music21.chord.Chord', 'B3', 'B4', 'C'], ['music21.note.Note', 'C'], ['music21.note.Note', 'C'], ['music21.note.Note', 'G'], ['music21.note.Note', 'G'], ['music21.note.Note', 'A'], ['music21.note.Note', 'C'], ['music21.note.Note', 'G'], ['music21.note.Note', 'G'], ['music21.note.Note', 'D'], ['music21.chord.Chord', 'A2', 'G3'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'C'], ['music21.note.Note', 'A'], ['music21.note.Note', 'C'], ['music21.note.Note', 'C'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B-'], ['music21.note.Note', 'C'], ['music21.note.Note', 'E-'], ['music21.chord.Chord', 'F'], ['music21.c21.note.Note', 'E'], ['music21.note.Note', 'G'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'B'], ['music21.note.Note', 'G'], ['music21.chord.Chord', 'G3', 'B3'], ['music21.note.Note', 'B'], ['music21.note.Note', 'F'], ['music21.note.Note', 'F'], ['music21.note.Note', 'G'], ['music21.note.Note', 'B'], ['music21.note.Note', 'B'], ['music21.note.Note', 'G'], ['music21.note.Note', 'A'], ['music21.note.Note', 'G'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'F'], ['music21.note.Note', 'E-'], ['music21.note.Note', 'F'], ['music21.note.Note', 'C'], ['music21.note.Note', 'B'], ['music21.note.Note', 'F'], ['music21.note.Note', 'G'], ['mu ...

# %%
s = stream.Stream()
for i in range(len(notes)):
    print(notes[i])
    if notes[i][0] == 'music21.note.Note':
        s.append(note.Note(notes[i][1]))
        print(i)
    elif notes[i][0] == 'music21.chord.Chord' :
        temp = [lel for lel in notes[i][1:]]
        print(temp)
        s.append(chord.Chord(temp))
# Out:
# ['music21.note.Note', 'B-']
# 0
# ['music21.note.Note', 'A']
# 1
# ['music21.note.Note', 'G']
# 2
# ['music21.note.Note', 'D']
# 3
# ['music21.note.Note', 'F']
# 4
# ['music21.note.Note', 'G']
# 5
# ['music21.note.Note', 'F']
# 6
# ['music21.note.Note', 'F']
# 7
# ['music21.note.Note', 'D']
# 8
# ['music21.note.Note', 'B-']
# 9
# ['music21.note.Note', 'G']
# 10
# ['music21.note.Note', 'B-']
# 11
# ['music21.note.Note', 'B']
# 12
# ['music21.note.Note', 'B-']
# 13
# ['music21.note.Note', 'F']
# 14
# ['music21.note.Note', 'F']
# 15
# ['music21.note.Note', 'C']
# 16
# ['music21.note.Note', 'C']
# 17
# ['music21.note.Note', 'G']
# 18
# ['music21.note.Note', 'F']
# 19
# ['music21.note.Note', 'D']
# 20
# ['music21.note.Note', 'C']
# 21
# ['music21.note.Note', 'B']
# 22
# ['music21.note.Note', 'G']
# 23
# ['music21.note.Note', 'E']
# 24
# ['music21.note.Note', 'G']
# 25
# ['music21.note.Note', 'G']
# 26
# ['music21.note.Note', 'B']
# 27
# ['music21.note.Note', 'G']
# 28
# ['music21.chord.Chord', 'B-1', 'G2']
# ['B-1', 'G2']
# ['music21.note.Note', 'B-']
# 30
# ['music21.note.Note', 'E']
# 31
# ['music21.chord.Chord', 'B3', 'E3']
# ['B3', 'E3']
# ['music21.note.Note', 'D']
# 33
# ['music21.note.Note', 'B-']
# 34
# ['music21.note.Note', 'F']
# 35
# ['music21.note.Note', 'G']
# 36
# ['music21.note.Note', 'D']
# 37
# ['music21.note.Note', 'E-']
# 38
# ['music21.noe.Note', 'B']
# ['music21.note.Note', 'D']
# 40
# ['music21.chord.Chord', 'B-3', 'G4']
# ['B-3', 'G4']
# ['music21.note.Note', 'G']
# 42
# ['music21.note.Note', 'B']
# 43
# ['music21.note.Note', 'D']
# 44
# ['music21.note.Note', 'G']
# 45
# ['music21.note.Note', 'G']
# 46
# ['music21.note.Note', 'B']
# 47
# ['music21.note.Note', 'C']
# 48
# ['music21.note.Note', 'B']
# 49
# ['music21.note.Note', 'B-']
# 50
# ['music21.note.Note', 'C']
# 51
# ['music21.note.Note', 'B-']
# 52
# ['music21.note.Note', 'B-']
# 53
# ['music21.chord.Chord', 'F']
# ['F']
# ['music21.note.Note', 'G']
# 55
# ['music21.note.Note', 'G']
# 56
# ['music21.note.Note', 'B-']
# 57
# ['music21.note.Note', 'F']
# 58
# ['music21.note.Note', 'G']
# 59
# ['music21.note.Note', 'D']
# 60
# ['music21.note.Note', 'E-']
# 61
# ['music21.note.Note', 'B-']
# 62
# ['music21.note.Note', 'D']
# 63
# ['music21.note.Note', 'F']
# 64
# ['music21.note.Note', 'C']
# 65
# ['music21.note.Note', 'E']
# 66
# ['music21.note.Note', 'D']
# 67
# ['music21.note.Note', 'G']
# 68
# ['music21.note.Note', 'E']
# 69
# ['music21.note.Note', 'C']
# 70
# ['music21.note.Note', 'F']
# 71
# ['music21.note.Note', 'E']
# 72
# ['music21.chord.Chord', 'D4', 'F4']
# ['D4', 'F4']
# ['music21.note.Note', 'E-']
# 74
# ['music21.chord.Chord', 'E3', 'C4']
# ['E3', 'C4']
# ['music21.chord.Chord', 'F3', 'A2']
# ['F3', 'A2']
# ['music21.chord.Chord', 'B-4', 'F']
# ['B-4', 'F']
# ['music21.note.Note', 'A']
# 78
# ['music21.note.Note', 'D']
# 79
# ['music21.note.Note', 'B-']
# 80
# ['music21.note.Note', 'G']
# 81
# ['music21.note.Note', 'C']
# 82
# ['music21.note.Note', 'C']
# 83
# ['music21.note.Note', 'B-']
# 84
# ['music21.note.Note', 'B-']
# 85
# ['music21.note.Note', 'E-']
# 86
# ['music21.note.Note', 'B-']
# 87
# ['music21.note.Note', 'A']
# 88
# ['music21.chord.Chord', 'G']
# ['G']
# ['music21.note.Note', 'A']
# 90
# ['music21.note.Note', 'A']
# 91
# ['music21.note.Note', 'B']
# 92
# ['music21.note.Note', 'C']
# 93
# ['music21.chord.Chord', 'B3', 'B4', 'C']
# ['B3', 'B4', 'C']
# ['music21.note.Note', 'C']
# 95
# ['music21.note.Note', 'C']
# 96
# ['music21.note.Note', 'G']
# 97
# ['music21.note.Note', 'G']
# 98
# ['music21.note.Note', 'A']
# 99
# ['music21.note.Note', 'C']
# 100
# ['music21.note.Note', 'G']
# 101
# ['music21.note.Note', 'G']
# 102
# ['music21.note.Note', 'D']
# 103
# ['music21.chord.Chord', 'A2', 'G3']
# ['A2', 'G3']
# ['music21.note.Note', 'E-']
# 105
# ['music21.note.Note', 'C']
# 106
# ['music21.note.Note', 'A']
# 107
# ['music21.note.Note', 'C']
# 108
# ['music21.note.Note', 'C']
# 109
# ['music21.note.Note', 'G']
# 110
# ['music21.note.Note', 'B-']
# 111
# ['music21.note.Note', 'C']
# 112
# ['music21.note.Note', 'E-']
# 113
# ['music21.chord.Chord', 'F']
# ['F']
# ['music21.c21.note.Note', 'E']
# ['music21.note.Note', 'G']
# 116
# ['music21.note.Note', 'E-']
# 117
# ['music21.note.Note', 'B']
# 118
# ['music21.note.Note', 'G']
# 119
# ['music21.chord.Chord', 'G3', 'B3']
# ['G3', 'B3']
# ['music21.note.Note', 'B']
# 121
# ['music21.note.Note', 'F']
# 122
# ['music21.note.Note', 'F']
# 123
# ['music21.note.Note', 'G']
# 124
# ['music21.note.Note', 'B']
# 125
# ['music21.note.Note', 'B']
# 126
# ['music21.note.Note', 'G']
# 127
# ['music21.note.Note', 'A']
# 128
# ['music21.note.Note', 'G']
# 129
# ['music21.note.Note', 'E-']
# 130
# ['music21.note.Note', 'F']
# 131
# ['music21.note.Note', 'E-']
# 132
# ['music21.note.Note', 'F']
# 133
# ['music21.note.Note', 'C']
# 134
# ['music21.note.Note', 'B']
# 135
# ['music21.note.Note', 'F']
# 136
# ['music21.note.Note', 'G']
# 137
# ['music21.note.Note', 'D']
# 138
# ['music21.note.Note', 'G']
# 139
# ['music21.note.Note', 'F']
# 140
# ['music21.note.Note', 'E']
# 141
# ['music21.note.Note', 'A']
# 142
# ['music21.chord.Chord', 'F6', 'C7']
# ['F6', 'C7']
# ['music21.note.Note', 'F']
# 144
# ['music21.note.Note', 'F']
# 145
# ['music21.note.Note', 'F']
# 146
# ['music21.note.Note', 'D']
# 147
# ['music21.note.Note', 'F']
# 148
# ['music21.note.Note', 'E-']
# 149
# ['music21.chord.Chord', 'A2', 'C3']
# ['A2', 'C3']
# ['music21.note.Note', 'F']
# 151
# ['music21.note.Note', 'B']
# 152
# ['music21.note.Note', 'B-']
# 153
# ['music21.note.Note', 'B']
# 154
# ['music21.note.Note', 'B']
# 155
# ['music21.note.Note', 'E-']
# 156
# ['music21.note.Note', 'E-']
# 157
# ['music21.note.Note', 'B']
# 158
# ['music21.note.Note', 'E']
# 159
# ['music21.note.Note', 'C']
# 160
# ['music21.note.Note', 'G']
# 161
# ['music21.note.Note', 'F']
# 162
# ['music21.note.Note', 'B-']
# 163
# ['music21.note.Note', 'D']
# 164
# ['music21.note.Note', 'E-']
# 165
# ['music21.note.Note', 'A']
# 166
# ['music21.note.Note', 'D']
# 167
# ['music21.note.Note', 'E-']
# 168
# ['music21.chord.Chord', 'F']
# ['F']
# ['music21.chord.Chord', 'G3', 'G4']
# ['G3', 'G4']
# ['music21.note.Note', 'C']
# 171
# ['music21.note.Note', 'B']
# 172
# ['music21.note.Note', 'C']
# 173
# ['music21.note.Note', 'C']
# 174
# ['music21.chord.Chord', 'F4', 'G4', 'E-5']
# ['F4', 'G4', 'E-5']
# ['music21.chord.Chord', 'G3', 'B-2', 'G3']
# ['G3', 'B-2', 'G3']
# ['music21.note.Note', 'C']
# 177
# ['music21.chord.Chord', 'F4', 'A4']
# ['F4', 'A4']
# ['music21.note.Note', 'G']
# 179
# ['music21.note.Note', 'C']
# 180
# ['music21.note.Note', 'B']
# 181
# ['music21.note.Note', 'E-1.note.Note', 'G']
# ---------------------------------------------------------------------------
# AccidentalException                       Traceback (most recent call last)
# <ipython-input-9-44a1327187d4> in <module>
#       3     print(notes[i])
#       4     if notes[i][0] == 'music21.note.Note':
# ----> 5         s.append(note.Note(notes[i][1]))
#       6         print(i)
#       7     elif notes[i][0] == 'music21.chord.Chord' :
#
# ~/.local/lib/python3.5/site-packages/music21/note.py in __init__(self, pitchName, **keywords)
#    1048                 self.pitch = pitchName
#    1049             else: # assume first argument is pitch
# -> 1050                 self.pitch = pitch.Pitch(pitchName, **keywords)
#    1051         else: # supply a default pitch
#    1052             name = 'C4'
#
# ~/.local/lib/python3.5/site-packages/music21/pitch.py in __init__(self, name, **keywords)
#    1669         if name is not None:
#    1670             if not common.isNum(name):
# -> 1671                 self._setName(name) # set based on string
#    1672             else: # is a number
#    1673                 if name < 12: # is a pitchClass
#
# ~/.local/lib/python3.5/site-packages/music21/pitch.py in _setName(self, usrStr)
#    2503         elif len(usrStr) > 1:
#    2504             self.step = usrStr[0]
# -> 2505             self.accidental = Accidental(usrStr[1:])
#    2506         else:
#    2507             raise PitchException('Cannot make a name out of %s' % repr(usrStr))
#
# ~/.local/lib/python3.5/site-packages/music21/pitch.py in __init__(self, specifier)
#     840         self._alter = 0.0     # semitones to alter step
#     841         # potentially can be a fraction... but not exponent...
# --> 842         self.set(specifier)
#     843
#     844     ### SPECIAL METHODS ###
#
# ~/.local/lib/python3.5/site-packages/music21/pitch.py in set(self, name, allowNonStandardValue)
#    1108         else:
#    1109             if not allowNonStandardValue:
# -> 1110                 raise AccidentalException('%s is not a supported accidental type' % name)
#    1111             else:
#    1112                 if isinstance(name, str):
#
# AccidentalException: -.note.note is not a supported accidental type

# %%
s.write('midi', fp='Generated.mid')
# Out:
# 'Generated.mid'
